# %% [markdown]
# # Intel® Robotics advancing physical AI development and deployment

# %% [markdown]
# ### Imitation learning from zero to deployment using Physical AI Studio

# %% [markdown]
# <img src="media/1. all Studio.png" width="800">

# %% [markdown]
# ## 1) Installation

# %% [markdown]
# <font size="4">[Video: Installation](https://youtu.be/7ciF8pAvTN8)

# %% [markdown]
# #### Find the instructions here: https://github.com/open-edge-platform/physical-ai-studio

# %% [markdown]
# ## 2) Connect Robots

# %% [markdown]
# <font size="4">[Video: Connect Robots ](https://youtu.be/ysbX80LL6J8)

# %% [markdown]
# <img src="media/robots.gif" width="800">

# %% [markdown]
# ## 3) Connect Cameras

# %% [markdown]
# <font size="4">[Video: Connect Cameras](https://youtu.be/K6128wmhBwA)

# %% [markdown]
# <img src="media/cameras.gif" width="800">

# %% [markdown]
# ## 4) Dataset recording

# %% [markdown]
# <font size="4">[Video: Dataset recording](https://youtu.be/H5yxKIxPx3o)

# %% [markdown]
# <img src="media/data-set.gif" width="800">

# %% [markdown]
# ## 5) Training

# %% [markdown]
# <font size="4">[Video: Model Training](https://youtu.be/NkADPzrCV8Y)

# %% [markdown]
# <img src="media/Train.gif" width="800">

# %% [markdown]
# ## 6) Test the result

# %% [markdown]
# #### Try the model directly from the studio

# %% [markdown]
# <img src="media/try-model-studio.png" width="800">

# %% [markdown]
# ## 7) Download a deployment package

# %% [markdown]
# #### Download a deployment package for your target device
# #### Follow the instructions and run the demo code

# %% [markdown]
# <img src="media/download-model.png" width="800">
